# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/home/ztang/multitask_RNA/data/RNA_loc/TableS2.csv',index_col=0)

# %%
#Matching Fig1B, confirming source of data
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(df['logFC(neurite/soma) - Neuro-2a'],bins = 100)
sns.histplot(df['logFC(neurite/soma) - CAD'],bins = 100)
plt.yscale('log')

# %%
import scipy.stats as stats
stats.pearsonr(df['logFC(neurite/soma) - CAD'],df['logFC(neurite/soma) - Neuro-2a'])
# Out:
# PearsonRResult(statistic=0.25962689631517416, pvalue=0.0)
